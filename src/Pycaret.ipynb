# %%
import pycaret
from pycaret.classification import *

# %%
from train_titanic import load_data, conform_data

# %%
data = conform_data(load_data())
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0       0.0     3.0  0.0  22.0    1.0    0.0   7.2500         0.0         0.0
# 1       1.0     1.0  1.0  38.0    1.0    0.0  71.2833         1.0         0.0
# 2       1.0     3.0  1.0  26.0    0.0    0.0   7.9250         0.0         0.0
# 3       1.0     1.0  1.0  35.0    1.0    0.0  53.1000         0.0         0.0
# 4       0.0     3.0  0.0  35.0    0.0    0.0   8.0500         0.0         0.0
#
#    Embarked_S
# 0         1.0
# 1         0.0
# 2         1.0
# 3         1.0
# 4         1.0

# %% [markdown]
# #### Setup do PyCaret

# %%
s = setup(data, target = 'Survived', session_id = 123, n_jobs = -2, log_experiment='mlflow', experiment_name='classificador_titanic')

# %%
exp = ClassificationExperiment()

# %%
exp.setup(data, target = 'Survived', session_id = 123, n_jobs = -2, log_experiment='mlflow', experiment_name='classificador_titanic')

# %%
best = exp.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             18:33:46
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_6d32b th {
#   text-align: left;
# }
# ...

# %%
exp.plot_model(best, plot='auc')
